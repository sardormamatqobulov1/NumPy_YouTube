# %% [markdown]
# <a href="https://colab.research.google.com/github/sardormamatqobulov1/NumPy_YouTube/blob/main/NumPy_Linear_Algebra_%26_Random_Walks_YouTube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
“Look at this diagram — on the left we have element-wise multiplication, and on the right, matrix multiplication.”

# %%
import numpy as np
x = np.array([[1.,2.,3.], [4.,5.,6.]])
y = np.array([[6., 23.], [-1,7], [8,9]])

# %%
#Matrix multiplication
x.dot(y)
#same as
np.dot (x, y)
# Out:
# array([[ 28.,  64.],
#        [ 67., 181.]])

# %%
x @ np.ones(3)
# Out:
# array([ 6., 15.])

# %%
from numpy.linalg import inv, qr
rng = np.random.default_rng(seed=42)
X = rng.standard_normal((5,5))
mat = X.T @ X

# %%
#Compute inverse
inv(mat)
# Out:
# array([[ 7.84438443e-01,  4.63616701e-01, -4.48384959e-01,
#         -5.40160666e-01, -6.94607117e-01],
#        [ 4.63616701e-01,  3.60721302e+00,  9.40885274e-01,
#         -1.26218773e+00, -1.97866405e+00],
#        [-4.48384959e-01,  9.40885274e-01,  1.11493368e+00,
#          7.50942259e-02, -2.42061387e-03],
#        [-5.40160666e-01, -1.26218773e+00,  7.50942259e-02,
#          1.04717109e+00,  1.06274844e+00],
#        [-6.94607117e-01, -1.97866405e+00, -2.42061387e-03,
#          1.06274844e+00,  1.64726226e+00]])

# %%
#Checkl identity
mat @ inv(mat)
# Out:
# array([[ 1.00000000e+00,  1.02513109e-16, -6.95323088e-17,
#         -3.30562158e-16,  8.16886482e-17],
#        [ 3.61004020e-16,  1.00000000e+00,  3.56678868e-16,
#         -1.34174532e-15, -9.21384070e-16],
#        [-2.54232657e-17, -1.35490593e-16,  1.00000000e+00,
#          4.27763408e-16, -5.63965157e-16],
#        [-1.85858349e-16, -3.87815277e-16,  1.35329085e-17,
#          1.00000000e+00, -1.71846722e-16],
#        [-3.51732440e-16,  8.48940545e-16,  5.00286093e-17,
#         -9.23511960e-16,  1.00000000e+00]])

# %% [markdown]
# #Random Walk Simulation

# %%
import random
position = 0
walk =[position]
nsteps = 1000

# %%
for _ in range(nsteps):
  step = 1 if random.randint(0,1) else -1
  position += step
  walk.append(position)

# %%
import matplotlib.pyplot as plt
plt.plot(walk[:100])

# %%
nsteps = 1000
rng = np.random.default_rng(seed=12345)
draw = rng.integers(0,2, size=nsteps)
steps = np.where(draw==0, 1, -1)
walk = steps.cumsum()

# %%
#Minimum and maximum postions
walk.min(), walk.max()
# Out:
# (np.int64(-8), np.int64(50))

# %%
#First crossing time when walk reaches +10
(np.abs(walk)>=10).argmax()
# Out:
# np.int64(155)
